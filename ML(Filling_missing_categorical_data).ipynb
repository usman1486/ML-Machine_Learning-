# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("C:\\Users\\usman\\Documents\\train.csv")

# %%
d.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df_cate=d.select_dtypes(include=['object'])

# %%
df_cate.shape
# Out:
# (1460, 43)

# %%
df_cate.isnull().sum().sum()
# Out:
# 6617

# %%
per_data=df_cate.isnull().sum()/df_cate.shape[0]*100
per_data
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
drop_col=per_data[per_data>10].keys()
drop_col
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df=df_cate.drop(columns=drop_col)
df
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 520

# %%
missing_data_col_name=[var for var in df.columns if df[var].isnull().sum()>0]

# %%
(missing_data_col_name)
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
df['Electrical'].value_counts()
# Out:
# SBrkr    1335
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df['Electrical'].mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
df['Electrical'].fillna(df['Electrical'].mode()[0])
# Out:
# 0       SBrkr
# 1       SBrkr
# 2       SBrkr
# 3       SBrkr
# 4       SBrkr
#         ...
# 1455    SBrkr
# 1456    SBrkr
# 1457    SBrkr
# 1458    FuseA
# 1459    SBrkr
# Name: Electrical, Length: 1460, dtype: object

# %%
for var in missing_data_col_name:
     (df[var].fillna(df[var].mode()[0],inplace=True))

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1460, 38)

# %%
#Now take a look towards data distribution 
#we cant use distplot plot due to categorical data
#we histplot to see data distibution
#we cant draw histplot if there is "NAN" Value present in the dataset
plt.figure(figsize=(16,9))
for i,var in enumerate(missing_data_col_name):
     plt.subplot(4,3,i+1)
     plt.hist(df[var],label="impute",color="yellow")
     plt.hist(df_cate[var].dropna(),label="Orignal",color="grey")
     plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f823ef7bbcc7> in <module>
#       3 #we histplot to see data distibution
#       4 #we cant draw histplot if there is "NAN" Value present in the dataset
# ----> 5 plt.figure(figsize=(16,9))
#       6 for i,var in enumerate(missing_data_col_name):
#       7      plt.subplot(4,3,i+1)
#
# NameError: name 'plt' is not defined
